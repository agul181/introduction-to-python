# %%
numberstek=list(range(1,10,2))
numbersçift=list(range(0,10,2))
numbersçift.extend(numberstek)
print(numbersçift)
timestwo = [i*2 for i in numbersçift]
print(timestwo)
# Out:
# [0, 2, 4, 6, 8, 1, 3, 5, 7, 9]
# [0, 4, 8, 12, 16, 2, 6, 10, 14, 18]
